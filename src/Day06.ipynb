# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# ### Filter respondents from Nepal

# %%
df['Country'] == 'Nepal'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %% [markdown]
# ### So, how many are from Nepal?

# %%
(df['Country'] == 'Nepal').value_counts()
# Out:
# False    88646
# True       237
# Name: Country, dtype: int64

# %% [markdown]
# ### Getting Nepal dataframe

# %%
filt_nepal = df['Country'] == 'Nepal'

# %%
df[filt_nepal]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %% [markdown]
# ### Another "ninja" way!

# %%
df[df['Country'] == 'Nepal']
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %% [markdown]
# ### Another way through `loc`

# %%
df.loc[filt_nepal]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %% [markdown]
# ### Lets see what Nepali think of their Managers

# %%
df.loc[filt_nepal,'MgrIdiot']
# Out:
# 506                         NaN
# 589                         NaN
# 980          Somewhat confident
# 1348         Somewhat confident
# 1775       Not at all confident
#                   ...
# 86082      Not at all confident
# 86205        Somewhat confident
# 86691    I don't have a manager
# 87026        Somewhat confident
# 87994        Somewhat confident
# Name: MgrIdiot, Length: 237, dtype: object

# %% [markdown]
# ### How to get the count?

# %%
df.loc[filt_nepal,'MgrIdiot'].value_counts()
# Out:
# Somewhat confident        66
# Very confident            28
# Not at all confident      23
# I don't have a manager     9
# Name: MgrIdiot, dtype: int64

# %% [markdown]
# ### Getting the plot of MgrIdiot

# %%
df.loc[filt_nepal,'MgrIdiot'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Using and operator for multiple queries

# %% [markdown]
# **Who are the Nepalese who think their manager is actually idiot?**

# %%
filt_idiot = (df['Country'] == 'Nepal') & (df['MgrIdiot'] == 'Not at all confident') 
filt_idiot
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Length: 88883, dtype: bool

# %%
df[filt_idiot]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 1775         1783  I am a developer by profession      Yes
# 4431         4452  I am a developer by profession      Yes
# 8354         8392  I am a developer by profession       No
# 8713         8751  I am a developer by profession      Yes
# 9819         9860  I am a developer by profession      Yes
# 12165       12222  I am a developer by profession      Yes
# 16410       16498  I am a developer by profession      Yes
# 25834       25984  I am a developer by profession      Yes
# 28988       29157  I am a developer by profession      Yes
# 32415       32610  I am a developer by profession      Yes
# 40357       40608  I am a developer by profession      Yes
# 40855       41114  I am a developer by profession      Yes
# 51711       52045  I am a developer by profession      Yes
# 60109       60493  I am a developer by profession      Yes
# 60774       61164     I code primarily as a hobby      Yes
# ...

# %% [markdown]
# ### Welcome change?

# %%
df.loc[filt_idiot,'WelcomeChange'].value_counts()
# Out:
# Just as welcome now as I felt last year                    15
# Somewhat less welcome now than last year                    2
# A lot more welcome now than last year                       2
# A lot less welcome now than last year                       2
# Not applicable - I did not use Stack Overflow last year     1
# Somewhat more welcome now than last year                    1
# Name: WelcomeChange, dtype: int64

# %%
df[filt_idiot]['WelcomeChange'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### High salary Nepalese

# %%
filt_salary = (df['Country'] == 'Nepal') & (df['ConvertedComp'] > 10000) 
df.loc[filt_salary]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 5968         5993  I am a developer by profession      Yes
# 25114       25261  I am a developer by profession      Yes
# 25897       26047  I am a developer by profession       No
# 39282       39526  I am a developer by profession      Yes
# 40383       40634  I am a developer by profession      Yes
# 42801       43075  I am a developer by profession       No
# 54821       55169  I am a developer by profession      Yes
# 61281       61673  I am a developer by profession       No
# 63428       63835  I am a developer by profession      Yes
# 77455       77938  I am a developer by profession       No
# 78532       79024  I am a developer by profession      Yes
# 81604       82113  I am a developer by profession      Yes
# 84918       85446  I am a developer by profession      Yes
# 86082       86618  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %% [markdown]
# ### What is their Employment type?

# %%
df.loc[filt_salary,'Employment']
# Out:
# 5968     Independent contractor, freelancer, or self-em...
# 25114    Independent contractor, freelancer, or self-em...
# 25897                                   Employed full-time
# 39282    Independent contractor, freelancer, or self-em...
# 40383                                   Employed full-time
# 42801    Independent contractor, freelancer, or self-em...
# 54821                                   Employed full-time
# 61281                                   Employed full-time
# 63428                                   Employed full-time
# 77455                                   Employed full-time
# 78532                                   Employed full-time
# 81604                                   Employed full-time
# 84918    Independent contractor, freelancer, or self-em...
# 86082                                   Employed full-time
# Name: Employment, dtype: object

# %%
df.loc[filt_salary,'Employment'].value_counts()
# Out:
# Employed full-time                                      9
# Independent contractor, freelancer, or self-employed    5
# Name: Employment, dtype: int64

# %% [markdown]
# ### What are Nepali people using as tech stack?

# %%
df.loc[filt_nepal,'LanguageWorkedWith']
# Out:
# 506                              C;C++;HTML/CSS;JavaScript
# 589                          C;C++;HTML/CSS;PHP;Python;SQL
# 980                                       C++;Go;Other(s):
# 1348               HTML/CSS;Java;JavaScript;SQL;TypeScript
# 1775                                                Python
#                                ...
# 86082                 HTML/CSS;Java;JavaScript;Python;Ruby
# 86205                                                  PHP
# 86691    Assembly;Bash/Shell/PowerShell;C;C++;Dart;HTML...
# 87026      C;C++;C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 87994                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageWorkedWith, Length: 237, dtype: object

# %% [markdown]
# ### Language + Salary

# %%
df.loc[filt_nepal,['LanguageWorkedWith','ConvertedComp']]
# Out:
#                                       LanguageWorkedWith  ConvertedComp
# 506                            C;C++;HTML/CSS;JavaScript            NaN
# 589                        C;C++;HTML/CSS;PHP;Python;SQL            NaN
# 980                                     C++;Go;Other(s):        10000.0
# 1348             HTML/CSS;Java;JavaScript;SQL;TypeScript         3168.0
# 1775                                              Python         1692.0
# ...                                                  ...            ...
# 86082               HTML/CSS;Java;JavaScript;Python;Ruby        12000.0
# 86205                                                PHP            NaN
# 86691  Assembly;Bash/Shell/PowerShell;C;C++;Dart;HTML...            NaN
# 87026    C;C++;C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript         2640.0
# 87994                 HTML/CSS;JavaScript;PHP;Python;SQL            NaN
#
# [237 rows x 2 columns]

# %%
df.loc[filt_nepal,'LanguageWorkedWith']
# Out:
# 506                              C;C++;HTML/CSS;JavaScript
# 589                          C;C++;HTML/CSS;PHP;Python;SQL
# 980                                       C++;Go;Other(s):
# 1348               HTML/CSS;Java;JavaScript;SQL;TypeScript
# 1775                                                Python
#                                ...
# 86082                 HTML/CSS;Java;JavaScript;Python;Ruby
# 86205                                                  PHP
# 86691    Assembly;Bash/Shell/PowerShell;C;C++;Dart;HTML...
# 87026      C;C++;C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 87994                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageWorkedWith, Length: 237, dtype: object

# %% [markdown]
# ### Python users from Nepal

# %%
df.loc[filt_nepal,'LanguageWorkedWith'].str.contains('Python')
# Out:
# 506      False
# 589       True
# 980      False
# 1348     False
# 1775      True
#          ...
# 86082     True
# 86205    False
# 86691     True
# 87026    False
# 87994     True
# Name: LanguageWorkedWith, Length: 237, dtype: object

# %%
df.loc[filt_nepal,'LanguageWorkedWith'].str.contains('C+\+').value_counts()
# Out:
# False    144
# True      80
# Name: LanguageWorkedWith, dtype: int64

# %% [markdown]
# ### Plotting the number of python users from Nepal

# %%
df.loc[filt_nepal,'LanguageWorkedWith'].str.contains('Python').value_counts().plot.bar()
# Out:
# <AxesSubplot:ylabel='LanguageWorkedWith'>
